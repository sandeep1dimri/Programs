# %% [markdown]
# # # Convert JSON file to CSV file

# %%
import pandas as pd
import json

# %%
# Open the file and load into data
with open('result2.json') as file:
    data = json.load(file)

# %%
data
# Out:
# [{'frame_id': 1, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 2, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 3, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 4, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 5, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 6, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 7, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 8, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 9, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 10, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 11, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 12, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 13, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 14, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 15, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 16, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 17, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 18, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 19, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 20, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 21, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 22, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 23, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 24, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 25,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.277149,
#      'center_y': 0.913651,
#      'width': 0.426809,
#      'height': 0.170062},
#     'confidence': 0.260731}]},
#  {'frame_id': 26, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 27,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.484067,
#      'center_y': 0.813543,
#      'width': 0.343799,
#      'height': 0.373212},
#     'confidence': 0.447967}]},
#  {'frame_id': 28,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.431598,
#      'center_y': 0.805347,
#      'width': 0.32898,
#      'height': 0.376041},
#     'confidence': 0.378137}]},
#  {'frame_id': 29, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 30, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 31, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 32, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 33,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.499317,
#      'center_y': 0.77615,
#      'width': 0.220084,
#      'height': 0.470351},
#     'confidence': 0.426009}]},
#  {'frame_id': 34, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 35, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 36,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.428471,
#      'center_y': 0.748015,
#      'width': 0.266568,
#      'height': 0.490872},
#     'confidence': 0.444865}]},
#  {'frame_id': 37,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.422993,
#      'center_y': 0.73731,
#      'width': 0.256923,
#      'height': 0.50662},
#     'confidence': 0.251297}]},
#  {'frame_id': 38,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.427645,
#      'center_y': 0.744454,
#      'width': 0.256502,
#      'height': 0.488883},
#     'confidence': 0.314086}]},
#  {'frame_id': 39,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.494426,
#      'center_y': 0.667527,
#      'width': 0.214753,
#      'height': 0.522133},
#     'confidence': 0.352956}]},
#  {'frame_id': 40,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.493085,
#      'center_y': 0.670938,
#      'width': 0.20452,
#      'height': 0.57973},
#     'confidence': 0.537274}]},
#  {'frame_id': 41, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 42, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 43,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.49551,
#      'center_y': 0.654469,
#      'width': 0.248172,
#      'height': 0.622164},
#     'confidence': 0.269724}]},
#  {'frame_id': 44, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 45, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 46, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 47,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.824172,
#      'center_y': 0.795278,
#      'width': 0.073481,
#      'height': 0.370097},
#     'confidence': 0.392017}]},
#  {'frame_id': 48,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.825346,
#      'center_y': 0.795229,
#      'width': 0.072222,
#      'height': 0.373278},
#     'confidence': 0.38059},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.430553,
#      'center_y': 0.65106,
#      'width': 0.282588,
#      'height': 0.613651},
#     'confidence': 0.274643}]},
#  {'frame_id': 49,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.421751,
#      'center_y': 0.645574,
#      'width': 0.274271,
#      'height': 0.619852},
#     'confidence': 0.288906}]},
#  {'frame_id': 50,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.425698,
#      'center_y': 0.646874,
#      'width': 0.299027,
#      'height': 0.6362},
#     'confidence': 0.317223}]},
#  {'frame_id': 51, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 52,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.476326,
#      'center_y': 0.606729,
#      'width': 0.110329,
#      'height': 0.333554},
#     'confidence': 0.294126}]},
#  {'frame_id': 53, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 54, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 55, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 56, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 57, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 58, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 59, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 60, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 61, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 62, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 63, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 64, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 65, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 66, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 67, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 68, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 69, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 70, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 71, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 72, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 73, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 74, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 75, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 76, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 77, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 78, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 79, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 80, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 81, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 82, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 83, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 84, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 85, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 86, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 87, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 88,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 79,
#     'name': 'toothbrush',
#     'relative_coordinates': {'center_x': 0.148544,
#      'center_y': 0.364041,
#      'width': 0.081064,
#      'height': 0.559417},
#     'confidence': 0.421076}]},
#  {'frame_id': 89,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 79,
#     'name': 'toothbrush',
#     'relative_coordinates': {'center_x': 0.148703,
#      'center_y': 0.361908,
#      'width': 0.078798,
#      'height': 0.564207},
#     'confidence': 0.305894}]},
#  {'frame_id': 90,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.36825,
#      'center_y': 0.671609,
#      'width': 0.680925,
#      'height': 0.676157},
#     'confidence': 0.626705}]},
#  {'frame_id': 91,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.408792,
#      'center_y': 0.571028,
#      'width': 0.751513,
#      'height': 0.858266},
#     'confidence': 0.971098}]},
#  {'frame_id': 92,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.421703,
#      'center_y': 0.514204,
#      'width': 0.721099,
#      'height': 0.929238},
#     'confidence': 0.963168},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.572815,
#      'center_y': 0.501598,
#      'width': 0.368148,
#      'height': 0.737995},
#     'confidence': 0.701808}]},
#  {'frame_id': 93,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.422307,
#      'center_y': 0.510225,
#      'width': 0.729905,
#      'height': 0.92428},
#     'confidence': 0.993054}]},
#  {'frame_id': 94,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.426502,
#      'center_y': 0.510106,
#      'width': 0.741657,
#      'height': 0.924054},
#     'confidence': 0.997442}]},
#  {'frame_id': 95,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.426669,
#      'center_y': 0.511187,
#      'width': 0.758228,
#      'height': 0.90134},
#     'confidence': 0.99858},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.668519,
#      'center_y': 0.501371,
#      'width': 0.282697,
#      'height': 0.650162},
#     'confidence': 0.375836}]},
#  {'frame_id': 96,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.42315,
#      'center_y': 0.519694,
#      'width': 0.726325,
#      'height': 0.896348},
#     'confidence': 0.994373},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.668327,
#      'center_y': 0.501075,
#      'width': 0.287277,
#      'height': 0.65169},
#     'confidence': 0.497267}]},
#  {'frame_id': 97,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.420851,
#      'center_y': 0.523614,
#      'width': 0.730706,
#      'height': 0.883061},
#     'confidence': 0.995419},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.665134,
#      'center_y': 0.503654,
#      'width': 0.321123,
#      'height': 0.662377},
#     'confidence': 0.33106}]},
#  {'frame_id': 98,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.411637,
#      'center_y': 0.550832,
#      'width': 0.755995,
#      'height': 0.887886},
#     'confidence': 0.996821},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.661036,
#      'center_y': 0.576232,
#      'width': 0.360708,
#      'height': 0.8151},
#     'confidence': 0.737469}]},
#  {'frame_id': 99,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.41123,
#      'center_y': 0.550272,
#      'width': 0.748796,
#      'height': 0.872047},
#     'confidence': 0.9974},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.655554,
#      'center_y': 0.580623,
#      'width': 0.371715,
#      'height': 0.79076},
#     'confidence': 0.463975}]},
#  {'frame_id': 100,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.415608,
#      'center_y': 0.552207,
#      'width': 0.736736,
#      'height': 0.87952},
#     'confidence': 0.998196},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.654651,
#      'center_y': 0.580779,
#      'width': 0.386922,
#      'height': 0.792316},
#     'confidence': 0.371396}]},
#  {'frame_id': 101,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.416945,
#      'center_y': 0.551335,
#      'width': 0.722473,
#      'height': 0.867794},
#     'confidence': 0.998709},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.648212,
#      'center_y': 0.584229,
#      'width': 0.399798,
#      'height': 0.794698},
#     'confidence': 0.337456}]},
#  {'frame_id': 102,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.41781,
#      'center_y': 0.558707,
#      'width': 0.731422,
#      'height': 0.868349},
#     'confidence': 0.998516}]},
#  {'frame_id': 103,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.419172,
#      'center_y': 0.557708,
#      'width': 0.725779,
#      'height': 0.871779},
#     'confidence': 0.998334}]},
#  {'frame_id': 104,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.420726,
#      'center_y': 0.556431,
#      'width': 0.71357,
#      'height': 0.859655},
#     'confidence': 0.998002}]},
#  {'frame_id': 105,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.4234,
#      'center_y': 0.554465,
#      'width': 0.716221,
#      'height': 0.860012},
#     'confidence': 0.998426}]},
#  {'frame_id': 106,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.421603,
#      'center_y': 0.554202,
#      'width': 0.724172,
#      'height': 0.861391},
#     'confidence': 0.997623}]},
#  {'frame_id': 107,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.419358,
#      'center_y': 0.557913,
#      'width': 0.724005,
#      'height': 0.858737},
#     'confidence': 0.998153}]},
#  {'frame_id': 108,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.416534,
#      'center_y': 0.558745,
#      'width': 0.730259,
#      'height': 0.850352},
#     'confidence': 0.998336}]},
#  {'frame_id': 109,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.415389,
#      'center_y': 0.561546,
#      'width': 0.718465,
#      'height': 0.845758},
#     'confidence': 0.99802},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.657131,
#      'center_y': 0.587678,
#      'width': 0.331114,
#      'height': 0.733286},
#     'confidence': 0.399914}]},
#  {'frame_id': 110,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.417895,
#      'center_y': 0.562339,
#      'width': 0.725483,
#      'height': 0.83892},
#     'confidence': 0.997137},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.658187,
#      'center_y': 0.584762,
#      'width': 0.336462,
#      'height': 0.713175},
#     'confidence': 0.369961}]},
#  {'frame_id': 111,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.276288,
#      'center_y': 0.575197,
#      'width': 0.372787,
#      'height': 0.874188},
#     'confidence': 0.995002}]},
#  {'frame_id': 112,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.271084,
#      'center_y': 0.569803,
#      'width': 0.386234,
#      'height': 0.878255},
#     'confidence': 0.995775}]},
#  {'frame_id': 113,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.267312,
#      'center_y': 0.570241,
#      'width': 0.399651,
#      'height': 0.870194},
#     'confidence': 0.993024}]},
#  {'frame_id': 114,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.263847,
#      'center_y': 0.571511,
#      'width': 0.408287,
#      'height': 0.857505},
#     'confidence': 0.992574}]},
#  {'frame_id': 115,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.27388,
#      'center_y': 0.586962,
#      'width': 0.411182,
#      'height': 0.834046},
#     'confidence': 0.892873}]},
#  {'frame_id': 116,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.292262,
#      'center_y': 0.588485,
#      'width': 0.405505,
#      'height': 0.825966},
#     'confidence': 0.956155}]},
#  {'frame_id': 117,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.341544,
#      'center_y': 0.675864,
#      'width': 0.297494,
#      'height': 0.572414},
#     'confidence': 0.39437}]},
#  {'frame_id': 118,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.336526,
#      'center_y': 0.716996,
#      'width': 0.334134,
#      'height': 0.545098},
#     'confidence': 0.712181}]},
#  {'frame_id': 119, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 120, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 121, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 122, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 123, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 124, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 125, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 126, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 127, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 128, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 129, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 130,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.282098,
#      'center_y': 0.62785,
#      'width': 0.133599,
#      'height': 0.82413},
#     'confidence': 0.968029},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.448376,
#      'center_y': 0.677367,
#      'width': 0.09082,
#      'height': 0.207805},
#     'confidence': 0.406246}]},
#  {'frame_id': 131,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.289833,
#      'center_y': 0.597372,
#      'width': 0.137321,
#      'height': 0.738816},
#     'confidence': 0.977001},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.448371,
#      'center_y': 0.669901,
#      'width': 0.123246,
#      'height': 0.219151},
#     'confidence': 0.379827}]},
#  {'frame_id': 132,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.285364,
#      'center_y': 0.59594,
#      'width': 0.131,
#      'height': 0.803478},
#     'confidence': 0.585963}]},
#  {'frame_id': 133, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 134,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 1,
#     'name': 'bicycle',
#     'relative_coordinates': {'center_x': 0.363282,
#      'center_y': 0.7162,
#      'width': 0.171979,
#      'height': 0.333701},
#     'confidence': 0.322946},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.362626,
#      'center_y': 0.575254,
#      'width': 0.213791,
#      'height': 0.631521},
#     'confidence': 0.865284}]},
#  {'frame_id': 135,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.407504,
#      'center_y': 0.587056,
#      'width': 0.278491,
#      'height': 0.660632},
#     'confidence': 0.912089}]},
#  {'frame_id': 136,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.421768,
#      'center_y': 0.728383,
#      'width': 0.301304,
#      'height': 0.425306},
#     'confidence': 0.941364},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.407155,
#      'center_y': 0.407298,
#      'width': 0.127808,
#      'height': 0.331035},
#     'confidence': 0.267671}]},
#  {'frame_id': 137,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.427716,
#      'center_y': 0.717548,
#      'width': 0.33267,
#      'height': 0.455089},
#     'confidence': 0.808031},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.435482,
#      'center_y': 0.586813,
#      'width': 0.297934,
#      'height': 0.704151},
#     'confidence': 0.971195}]},
#  {'frame_id': 138,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.425564,
#      'center_y': 0.718428,
#      'width': 0.351663,
#      'height': 0.461159},
#     'confidence': 0.924219},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.42749,
#      'center_y': 0.581666,
#      'width': 0.314709,
#      'height': 0.707536},
#     'confidence': 0.832327},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.37516,
#      'center_y': 0.406939,
#      'width': 0.103914,
#      'height': 0.313653},
#     'confidence': 0.344519}]},
#  {'frame_id': 139,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.423576,
#      'center_y': 0.717057,
#      'width': 0.377548,
#      'height': 0.470622},
#     'confidence': 0.986517},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.417078,
#      'center_y': 0.575143,
#      'width': 0.298878,
#      'height': 0.676854},
#     'confidence': 0.700764},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.39296,
#      'center_y': 0.404938,
#      'width': 0.112089,
#      'height': 0.297136},
#     'confidence': 0.335258}]},
#  {'frame_id': 140,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.424744,
#      'center_y': 0.718306,
#      'width': 0.377335,
#      'height': 0.471426},
#     'confidence': 0.985708},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.478211,
#      'center_y': 0.567975,
#      'width': 0.251783,
#      'height': 0.63516},
#     'confidence': 0.864615},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.397967,
#      'center_y': 0.407849,
#      'width': 0.103402,
#      'height': 0.270486},
#     'confidence': 0.333611}]},
#  {'frame_id': 141,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.416155,
#      'center_y': 0.718832,
#      'width': 0.408172,
#      'height': 0.478236},
#     'confidence': 0.284477},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.416155,
#      'center_y': 0.718832,
#      'width': 0.408172,
#      'height': 0.478236},
#     'confidence': 0.459849},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.407437,
#      'center_y': 0.406325,
#      'width': 0.11062,
#      'height': 0.281927},
#     'confidence': 0.384708},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.419962,
#      'center_y': 0.675777,
#      'width': 0.376744,
#      'height': 0.481139},
#     'confidence': 0.358056}]},
#  {'frame_id': 142,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.481735,
#      'center_y': 0.563733,
#      'width': 0.224022,
#      'height': 0.687826},
#     'confidence': 0.763321}]},
#  {'frame_id': 143,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.441218,
#      'center_y': 0.721865,
#      'width': 0.321195,
#      'height': 0.459958},
#     'confidence': 0.712464},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.482118,
#      'center_y': 0.564009,
#      'width': 0.242294,
#      'height': 0.723009},
#     'confidence': 0.909422}]},
#  {'frame_id': 144,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44504,
#      'center_y': 0.719776,
#      'width': 0.295538,
#      'height': 0.491551},
#     'confidence': 0.944366},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.448328,
#      'center_y': 0.562945,
#      'width': 0.281055,
#      'height': 0.751529},
#     'confidence': 0.934466}]},
#  {'frame_id': 145,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.446381,
#      'center_y': 0.712732,
#      'width': 0.284047,
#      'height': 0.505546},
#     'confidence': 0.962646},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.478359,
#      'center_y': 0.559295,
#      'width': 0.248481,
#      'height': 0.765204},
#     'confidence': 0.977719}]},
#  {'frame_id': 146,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.443071,
#      'center_y': 0.713394,
#      'width': 0.294419,
#      'height': 0.509918},
#     'confidence': 0.954762},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.44384,
#      'center_y': 0.56943,
#      'width': 0.273457,
#      'height': 0.756093},
#     'confidence': 0.931174}]},
#  {'frame_id': 147,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.442113,
#      'center_y': 0.667273,
#      'width': 0.315755,
#      'height': 0.545939},
#     'confidence': 0.534834},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.443806,
#      'center_y': 0.716689,
#      'width': 0.306249,
#      'height': 0.463843},
#     'confidence': 0.27822},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.439008,
#      'center_y': 0.569714,
#      'width': 0.291134,
#      'height': 0.748401},
#     'confidence': 0.639857}]},
#  {'frame_id': 148,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.444805,
#      'center_y': 0.673174,
#      'width': 0.306121,
#      'height': 0.535693},
#     'confidence': 0.804454},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.444805,
#      'center_y': 0.673174,
#      'width': 0.306121,
#      'height': 0.535693},
#     'confidence': 0.824775},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.444232,
#      'center_y': 0.562829,
#      'width': 0.264296,
#      'height': 0.767127},
#     'confidence': 0.833134}]},
#  {'frame_id': 149,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.470736,
#      'center_y': 0.670452,
#      'width': 0.307498,
#      'height': 0.53271},
#     'confidence': 0.463374},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.450869,
#      'center_y': 0.671812,
#      'width': 0.286438,
#      'height': 0.547815},
#     'confidence': 0.773707},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.445662,
#      'center_y': 0.570946,
#      'width': 0.267575,
#      'height': 0.708929},
#     'confidence': 0.367924}]},
#  {'frame_id': 150, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 151,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449259,
#      'center_y': 0.660818,
#      'width': 0.265169,
#      'height': 0.5686},
#     'confidence': 0.447875},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474583,
#      'center_y': 0.575713,
#      'width': 0.252071,
#      'height': 0.751009},
#     'confidence': 0.862036}]},
#  {'frame_id': 152,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 24,
#     'name': 'backpack',
#     'relative_coordinates': {'center_x': 0.408684,
#      'center_y': 0.780608,
#      'width': 0.172877,
#      'height': 0.336182},
#     'confidence': 0.320921},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44784,
#      'center_y': 0.648409,
#      'width': 0.268284,
#      'height': 0.591402},
#     'confidence': 0.291699},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.479586,
#      'center_y': 0.576794,
#      'width': 0.244898,
#      'height': 0.774702},
#     'confidence': 0.95605}]},
#  {'frame_id': 153,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.443066,
#      'center_y': 0.646414,
#      'width': 0.269112,
#      'height': 0.608485},
#     'confidence': 0.610208},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.478511,
#      'center_y': 0.580465,
#      'width': 0.247636,
#      'height': 0.777385},
#     'confidence': 0.966183}]},
#  {'frame_id': 154,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.448078,
#      'center_y': 0.653478,
#      'width': 0.286414,
#      'height': 0.589634},
#     'confidence': 0.799924},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.475198,
#      'center_y': 0.572618,
#      'width': 0.241936,
#      'height': 0.766484},
#     'confidence': 0.957755}]},
#  {'frame_id': 155,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.474306,
#      'center_y': 0.657004,
#      'width': 0.299911,
#      'height': 0.586975},
#     'confidence': 0.711067},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44813,
#      'center_y': 0.655117,
#      'width': 0.311714,
#      'height': 0.606755},
#     'confidence': 0.492135},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.476763,
#      'center_y': 0.570975,
#      'width': 0.261171,
#      'height': 0.735607},
#     'confidence': 0.864251}]},
#  {'frame_id': 156,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.475651,
#      'center_y': 0.655882,
#      'width': 0.312135,
#      'height': 0.59962},
#     'confidence': 0.585366},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44608,
#      'center_y': 0.656043,
#      'width': 0.327136,
#      'height': 0.609638},
#     'confidence': 0.481718},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.477417,
#      'center_y': 0.57247,
#      'width': 0.274576,
#      'height': 0.753733},
#     'confidence': 0.892308}]},
#  {'frame_id': 157,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.476277,
#      'center_y': 0.644848,
#      'width': 0.315777,
#      'height': 0.625406},
#     'confidence': 0.508862},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.446614,
#      'center_y': 0.647456,
#      'width': 0.323661,
#      'height': 0.623579},
#     'confidence': 0.279673},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.477234,
#      'center_y': 0.580672,
#      'width': 0.27257,
#      'height': 0.727658},
#     'confidence': 0.927176}]},
#  {'frame_id': 158,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.47662,
#      'center_y': 0.645839,
#      'width': 0.318546,
#      'height': 0.620775},
#     'confidence': 0.442099},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.444771,
#      'center_y': 0.649321,
#      'width': 0.32586,
#      'height': 0.626297},
#     'confidence': 0.290465},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.477663,
#      'center_y': 0.578946,
#      'width': 0.279016,
#      'height': 0.725428},
#     'confidence': 0.9186}]},
#  {'frame_id': 159,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.475871,
#      'center_y': 0.648748,
#      'width': 0.325812,
#      'height': 0.622078},
#     'confidence': 0.563236},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.445528,
#      'center_y': 0.651004,
#      'width': 0.331592,
#      'height': 0.634073},
#     'confidence': 0.378344},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.478036,
#      'center_y': 0.578534,
#      'width': 0.27695,
#      'height': 0.723652},
#     'confidence': 0.858218}]},
#  {'frame_id': 160,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.475313,
#      'center_y': 0.644551,
#      'width': 0.316888,
#      'height': 0.632605},
#     'confidence': 0.554897},
#    {'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.448956,
#      'center_y': 0.64566,
#      'width': 0.306082,
#      'height': 0.639556},
#     'confidence': 0.305308},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.478121,
#      'center_y': 0.581344,
#      'width': 0.269946,
#      'height': 0.723469},
#     'confidence': 0.892612}]},
#  {'frame_id': 161,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.448042,
#      'center_y': 0.646127,
#      'width': 0.311378,
#      'height': 0.637454},
#     'confidence': 0.345575},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.477196,
#      'center_y': 0.582365,
#      'width': 0.270606,
#      'height': 0.73048},
#     'confidence': 0.943589}]},
#  {'frame_id': 162,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.446105,
#      'center_y': 0.644558,
#      'width': 0.315077,
#      'height': 0.630374},
#     'confidence': 0.261616},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.446105,
#      'center_y': 0.644558,
#      'width': 0.315077,
#      'height': 0.630374},
#     'confidence': 0.592133},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474569,
#      'center_y': 0.581992,
#      'width': 0.276154,
#      'height': 0.720044},
#     'confidence': 0.938659}]},
#  {'frame_id': 163,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.444387,
#      'center_y': 0.646281,
#      'width': 0.31553,
#      'height': 0.6096},
#     'confidence': 0.316202},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.444387,
#      'center_y': 0.646281,
#      'width': 0.31553,
#      'height': 0.6096},
#     'confidence': 0.802177},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474676,
#      'center_y': 0.5818,
#      'width': 0.268439,
#      'height': 0.709371},
#     'confidence': 0.943127}]},
#  {'frame_id': 164,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.442978,
#      'center_y': 0.649601,
#      'width': 0.327318,
#      'height': 0.616612},
#     'confidence': 0.536015},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.442978,
#      'center_y': 0.649601,
#      'width': 0.327318,
#      'height': 0.616612},
#     'confidence': 0.829076},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.473618,
#      'center_y': 0.581165,
#      'width': 0.265392,
#      'height': 0.706444},
#     'confidence': 0.952772}]},
#  {'frame_id': 165,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44448,
#      'center_y': 0.652172,
#      'width': 0.321556,
#      'height': 0.615491},
#     'confidence': 0.570761},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.44448,
#      'center_y': 0.652172,
#      'width': 0.321556,
#      'height': 0.615491},
#     'confidence': 0.68388},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.472165,
#      'center_y': 0.584541,
#      'width': 0.276871,
#      'height': 0.711521},
#     'confidence': 0.961381}]},
#  {'frame_id': 166,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.440955,
#      'center_y': 0.650404,
#      'width': 0.340408,
#      'height': 0.62474},
#     'confidence': 0.395097},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.440955,
#      'center_y': 0.650404,
#      'width': 0.340408,
#      'height': 0.62474},
#     'confidence': 0.708067},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.445167,
#      'center_y': 0.582504,
#      'width': 0.297924,
#      'height': 0.727342},
#     'confidence': 0.927452}]},
#  {'frame_id': 167,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.440845,
#      'center_y': 0.643874,
#      'width': 0.342727,
#      'height': 0.64291},
#     'confidence': 0.323188},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.440845,
#      'center_y': 0.643874,
#      'width': 0.342727,
#      'height': 0.64291},
#     'confidence': 0.671009},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.445129,
#      'center_y': 0.583927,
#      'width': 0.300762,
#      'height': 0.732636},
#     'confidence': 0.924881}]},
#  {'frame_id': 168,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.440798,
#      'center_y': 0.644549,
#      'width': 0.335148,
#      'height': 0.6403},
#     'confidence': 0.350429},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.440798,
#      'center_y': 0.644549,
#      'width': 0.335148,
#      'height': 0.6403},
#     'confidence': 0.637004},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.444617,
#      'center_y': 0.583298,
#      'width': 0.296357,
#      'height': 0.740487},
#     'confidence': 0.946701}]},
#  {'frame_id': 169,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.445128,
#      'center_y': 0.643399,
#      'width': 0.320275,
#      'height': 0.638153},
#     'confidence': 0.435984},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.445128,
#      'center_y': 0.643399,
#      'width': 0.320275,
#      'height': 0.638153},
#     'confidence': 0.362985},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.472805,
#      'center_y': 0.586617,
#      'width': 0.273077,
#      'height': 0.719186},
#     'confidence': 0.971526}]},
#  {'frame_id': 170,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.445446,
#      'center_y': 0.643089,
#      'width': 0.31479,
#      'height': 0.6347},
#     'confidence': 0.644143},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.471531,
#      'center_y': 0.587242,
#      'width': 0.280009,
#      'height': 0.725238},
#     'confidence': 0.973486}]},
#  {'frame_id': 171,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.446252,
#      'center_y': 0.641164,
#      'width': 0.319108,
#      'height': 0.632211},
#     'confidence': 0.414541},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.471762,
#      'center_y': 0.588759,
#      'width': 0.286543,
#      'height': 0.720148},
#     'confidence': 0.978378}]},
#  {'frame_id': 172,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44828,
#      'center_y': 0.645773,
#      'width': 0.306682,
#      'height': 0.622886},
#     'confidence': 0.439402},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.471402,
#      'center_y': 0.585362,
#      'width': 0.280084,
#      'height': 0.721697},
#     'confidence': 0.983918}]},
#  {'frame_id': 173,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449956,
#      'center_y': 0.649772,
#      'width': 0.309431,
#      'height': 0.61338},
#     'confidence': 0.585404},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.472782,
#      'center_y': 0.583237,
#      'width': 0.280364,
#      'height': 0.7369},
#     'confidence': 0.986877}]},
#  {'frame_id': 174,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.450208,
#      'center_y': 0.645079,
#      'width': 0.308788,
#      'height': 0.623381},
#     'confidence': 0.488771},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.473382,
#      'center_y': 0.583253,
#      'width': 0.27664,
#      'height': 0.747753},
#     'confidence': 0.979315}]},
#  {'frame_id': 175,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.450763,
#      'center_y': 0.644929,
#      'width': 0.309223,
#      'height': 0.609751},
#     'confidence': 0.416454},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474273,
#      'center_y': 0.583702,
#      'width': 0.276112,
#      'height': 0.736622},
#     'confidence': 0.98166}]},
#  {'frame_id': 176,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449756,
#      'center_y': 0.645437,
#      'width': 0.306054,
#      'height': 0.607843},
#     'confidence': 0.3202},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474982,
#      'center_y': 0.583545,
#      'width': 0.277776,
#      'height': 0.73653},
#     'confidence': 0.98804}]},
#  {'frame_id': 177,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.473878,
#      'center_y': 0.58259,
#      'width': 0.280912,
#      'height': 0.74293},
#     'confidence': 0.989363}]},
#  {'frame_id': 178,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449502,
#      'center_y': 0.646734,
#      'width': 0.311731,
#      'height': 0.6194},
#     'confidence': 0.289431},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474769,
#      'center_y': 0.583965,
#      'width': 0.275159,
#      'height': 0.729278},
#     'confidence': 0.989366}]},
#  {'frame_id': 179,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449193,
#      'center_y': 0.647139,
#      'width': 0.306946,
#      'height': 0.612689},
#     'confidence': 0.262866},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474247,
#      'center_y': 0.583448,
#      'width': 0.276413,
#      'height': 0.723729},
#     'confidence': 0.986272}]},
#  {'frame_id': 180,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.448999,
#      'center_y': 0.649336,
#      'width': 0.310643,
#      'height': 0.616162},
#     'confidence': 0.347641},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.448999,
#      'center_y': 0.649336,
#      'width': 0.310643,
#      'height': 0.616162},
#     'confidence': 0.309004},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.474262,
#      'center_y': 0.583164,
#      'width': 0.270697,
#      'height': 0.736688},
#     'confidence': 0.980075}]},
#  {'frame_id': 181,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449672,
#      'center_y': 0.649446,
#      'width': 0.309697,
#      'height': 0.608907},
#     'confidence': 0.410691},
#    {'class_id': 17,
#     'name': 'horse',
#     'relative_coordinates': {'center_x': 0.449672,
#      'center_y': 0.649446,
#      'width': 0.309697,
#      'height': 0.608907},
#     'confidence': 0.33379},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.475617,
#      'center_y': 0.582857,
#      'width': 0.267593,
#      'height': 0.74053},
#     'confidence': 0.97693}]},
#  {'frame_id': 182,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.44963,
#      'center_y': 0.649104,
#      'width': 0.300566,
#      'height': 0.606596},
#     'confidence': 0.437478},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.477462,
#      'center_y': 0.582313,
#      'width': 0.261551,
#      'height': 0.732689},
#     'confidence': 0.969348}]},
#  {'frame_id': 183,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449352,
#      'center_y': 0.648219,
#      'width': 0.305088,
#      'height': 0.599136},
#     'confidence': 0.503161},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.476563,
#      'center_y': 0.581272,
#      'width': 0.268522,
#      'height': 0.735738},
#     'confidence': 0.974279}]},
#  {'frame_id': 184,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.449402,
#      'center_y': 0.648492,
#      'width': 0.306326,
#      'height': 0.60148},
#     'confidence': 0.528498},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.476611,
#      'center_y': 0.582497,
#      'width': 0.271451,
#      'height': 0.737592},
#     'confidence': 0.968749}]},
#  {'frame_id': 185,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.450012,
#      'center_y': 0.649909,
#      'width': 0.313123,
#      'height': 0.603388},
#     'confidence': 0.631786},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.476787,
#      'center_y': 0.581773,
#      'width': 0.272061,
#      'height': 0.740037},
#     'confidence': 0.975796}]},
#  {'frame_id': 186,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 3,
#     'name': 'motorbike',
#     'relative_coordinates': {'center_x': 0.448491,
#      'center_y': 0.654228,
#      'width': 0.314426,
#      'height': 0.594707},
#     'confidence': 0.772708},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.473807,
#      'center_y': 0.580419,
#      'width': 0.275557,
#      'height': 0.729743},
# ...
#      'height': 0.538009},
#     'confidence': 0.379047}]},
#  {'frame_id': 362,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.409641,
#      'center_y': 0.752337,
#      'width': 0.332904,
#      'height': 0.482934},
#     'confidence': 0.862525},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.648097,
#      'center_y': 0.572922,
#      'width': 0.210456,
#      'height': 0.555518},
#     'confidence': 0.73073}]},
#  {'frame_id': 363,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 21,
#     'name': 'bear',
#     'relative_coordinates': {'center_x': 0.406053,
#      'center_y': 0.75515,
#      'width': 0.312934,
#      'height': 0.46407},
#     'confidence': 0.495356},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.638376,
#      'center_y': 0.586192,
#      'width': 0.208077,
#      'height': 0.591542},
#     'confidence': 0.978144},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.410701,
#      'center_y': 0.777492,
#      'width': 0.29658,
#      'height': 0.452723},
#     'confidence': 0.706378}]},
#  {'frame_id': 364,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.641082,
#      'center_y': 0.561179,
#      'width': 0.128944,
#      'height': 0.510795},
#     'confidence': 0.66179},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.413556,
#      'center_y': 0.780972,
#      'width': 0.312655,
#      'height': 0.429718},
#     'confidence': 0.468267}]},
#  {'frame_id': 365,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.406094,
#      'center_y': 0.747038,
#      'width': 0.316178,
#      'height': 0.465813},
#     'confidence': 0.465725},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.63542,
#      'center_y': 0.558265,
#      'width': 0.13444,
#      'height': 0.508823},
#     'confidence': 0.377911}]},
#  {'frame_id': 366,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.642971,
#      'center_y': 0.592785,
#      'width': 0.228134,
#      'height': 0.549257},
#     'confidence': 0.78827},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.406744,
#      'center_y': 0.73749,
#      'width': 0.303155,
#      'height': 0.479063},
#     'confidence': 0.430777}]},
#  {'frame_id': 367,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.41467,
#      'center_y': 0.784859,
#      'width': 0.327055,
#      'height': 0.39411},
#     'confidence': 0.397762},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.476417,
#      'center_y': 0.784142,
#      'width': 0.134167,
#      'height': 0.403407},
#     'confidence': 0.272291}]},
#  {'frame_id': 368,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.477125,
#      'center_y': 0.786041,
#      'width': 0.127539,
#      'height': 0.412092},
#     'confidence': 0.640993},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.412154,
#      'center_y': 0.899148,
#      'width': 0.282938,
#      'height': 0.197648},
#     'confidence': 0.254248}]},
#  {'frame_id': 369, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 370,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.425507,
#      'center_y': 0.779255,
#      'width': 0.260254,
#      'height': 0.437732},
#     'confidence': 0.353773}]},
#  {'frame_id': 371,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.427804,
#      'center_y': 0.746623,
#      'width': 0.249269,
#      'height': 0.50354},
#     'confidence': 0.415432}]},
#  {'frame_id': 372,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.471766,
#      'center_y': 0.781732,
#      'width': 0.145629,
#      'height': 0.446714},
#     'confidence': 0.718888}]},
#  {'frame_id': 373,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.47209,
#      'center_y': 0.782544,
#      'width': 0.134117,
#      'height': 0.441384},
#     'confidence': 0.679184}]},
#  {'frame_id': 374,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.472973,
#      'center_y': 0.782776,
#      'width': 0.134617,
#      'height': 0.437847},
#     'confidence': 0.489425}]},
#  {'frame_id': 375,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.475803,
#      'center_y': 0.780868,
#      'width': 0.139895,
#      'height': 0.435498},
#     'confidence': 0.635078},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.481669,
#      'center_y': 0.520916,
#      'width': 0.166923,
#      'height': 0.304688},
#     'confidence': 0.284138}]},
#  {'frame_id': 376,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.42052,
#      'center_y': 0.782175,
#      'width': 0.264297,
#      'height': 0.426646},
#     'confidence': 0.592158},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.475054,
#      'center_y': 0.756141,
#      'width': 0.126831,
#      'height': 0.443278},
#     'confidence': 0.342898}]},
#  {'frame_id': 377,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.420234,
#      'center_y': 0.782984,
#      'width': 0.283327,
#      'height': 0.414418},
#     'confidence': 0.437262}]},
#  {'frame_id': 378,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.416862,
#      'center_y': 0.78426,
#      'width': 0.292633,
#      'height': 0.409592},
#     'confidence': 0.436576}]},
#  {'frame_id': 379,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.418461,
#      'center_y': 0.786355,
#      'width': 0.310087,
#      'height': 0.400483},
#     'confidence': 0.286021}]},
#  {'frame_id': 380,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.422244,
#      'center_y': 0.738488,
#      'width': 0.311694,
#      'height': 0.49148},
#     'confidence': 0.425064}]},
#  {'frame_id': 381,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.43037,
#      'center_y': 0.745145,
#      'width': 0.265419,
#      'height': 0.49177},
#     'confidence': 0.577831}]},
#  {'frame_id': 382,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.415202,
#      'center_y': 0.669222,
#      'width': 0.285412,
#      'height': 0.691659},
#     'confidence': 0.757453}]},
#  {'frame_id': 383,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.423147,
#      'center_y': 0.727289,
#      'width': 0.272918,
#      'height': 0.532514},
#     'confidence': 0.498606}]},
#  {'frame_id': 384,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.424293,
#      'center_y': 0.788516,
#      'width': 0.276826,
#      'height': 0.410143},
#     'confidence': 0.582532}]},
#  {'frame_id': 385,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.420445,
#      'center_y': 0.733742,
#      'width': 0.304378,
#      'height': 0.516958},
#     'confidence': 0.52774}]},
#  {'frame_id': 386,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.420365,
#      'center_y': 0.736693,
#      'width': 0.307905,
#      'height': 0.47404},
#     'confidence': 0.341062}]},
#  {'frame_id': 387,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.42972,
#      'center_y': 0.794785,
#      'width': 0.313607,
#      'height': 0.39759},
#     'confidence': 0.460264}]},
#  {'frame_id': 388,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.429032,
#      'center_y': 0.801067,
#      'width': 0.33026,
#      'height': 0.378629},
#     'confidence': 0.521917}]},
#  {'frame_id': 389,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.49549,
#      'center_y': 0.713255,
#      'width': 0.246522,
#      'height': 0.571841},
#     'confidence': 0.255884}]},
#  {'frame_id': 390, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 391, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 392,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.439109,
#      'center_y': 0.595896,
#      'width': 0.109974,
#      'height': 0.352325},
#     'confidence': 0.368387}]},
#  {'frame_id': 393, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 394, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 395,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.341258,
#      'center_y': 0.508149,
#      'width': 0.582706,
#      'height': 0.988997},
#     'confidence': 0.665107}]},
#  {'frame_id': 396,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.351767,
#      'center_y': 0.50308,
#      'width': 0.660484,
#      'height': 1.028514},
#     'confidence': 0.754407},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.504686,
#      'center_y': 0.505207,
#      'width': 0.293497,
#      'height': 0.874672},
#     'confidence': 0.257635}]},
#  {'frame_id': 397,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.411447,
#      'center_y': 0.497533,
#      'width': 0.615796,
#      'height': 0.953953},
#     'confidence': 0.916405}]},
#  {'frame_id': 398,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.411388,
#      'center_y': 0.502446,
#      'width': 0.690095,
#      'height': 0.930926},
#     'confidence': 0.892329}]},
#  {'frame_id': 399,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.414255,
#      'center_y': 0.515375,
#      'width': 0.665833,
#      'height': 0.919816},
#     'confidence': 0.987661}]},
#  {'frame_id': 400,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.427551,
#      'center_y': 0.514518,
#      'width': 0.655657,
#      'height': 0.902931},
#     'confidence': 0.979993}]},
#  {'frame_id': 401,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.432315,
#      'center_y': 0.546573,
#      'width': 0.606237,
#      'height': 0.884548},
#     'confidence': 0.974069}]},
#  {'frame_id': 402,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.422785,
#      'center_y': 0.551601,
#      'width': 0.586173,
#      'height': 0.885626},
#     'confidence': 0.972426}]},
#  {'frame_id': 403,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.413513,
#      'center_y': 0.529015,
#      'width': 0.585021,
#      'height': 0.824254},
#     'confidence': 0.90521}]},
#  {'frame_id': 404,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.423202,
#      'center_y': 0.550056,
#      'width': 0.606637,
#      'height': 0.865847},
#     'confidence': 0.975665}]},
#  {'frame_id': 405,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.427409,
#      'center_y': 0.552952,
#      'width': 0.608581,
#      'height': 0.873597},
#     'confidence': 0.943448}]},
#  {'frame_id': 406,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.420329,
#      'center_y': 0.555706,
#      'width': 0.551435,
#      'height': 0.866452},
#     'confidence': 0.995845}]},
#  {'frame_id': 407,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.419193,
#      'center_y': 0.552446,
#      'width': 0.551953,
#      'height': 0.893784},
#     'confidence': 0.994152}]},
#  {'frame_id': 408,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.415028,
#      'center_y': 0.514306,
#      'width': 0.529177,
#      'height': 0.967297},
#     'confidence': 0.974442}]},
#  {'frame_id': 409,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.411567,
#      'center_y': 0.507776,
#      'width': 0.542459,
#      'height': 0.930704},
#     'confidence': 0.99421}]},
#  {'frame_id': 410,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 43,
#     'name': 'knife',
#     'relative_coordinates': {'center_x': 0.700586,
#      'center_y': 0.437784,
#      'width': 0.155999,
#      'height': 0.208588},
#     'confidence': 0.266805},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.412851,
#      'center_y': 0.510351,
#      'width': 0.536654,
#      'height': 0.934509},
#     'confidence': 0.983953}]},
#  {'frame_id': 411,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 43,
#     'name': 'knife',
#     'relative_coordinates': {'center_x': 0.715698,
#      'center_y': 0.442294,
#      'width': 0.157257,
#      'height': 0.237727},
#     'confidence': 0.50557},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.42054,
#      'center_y': 0.508323,
#      'width': 0.518741,
#      'height': 0.901475},
#     'confidence': 0.964054}]},
#  {'frame_id': 412,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.429107,
#      'center_y': 0.497264,
#      'width': 0.547453,
#      'height': 0.959659},
#     'confidence': 0.975796}]},
#  {'frame_id': 413,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.429068,
#      'center_y': 0.503334,
#      'width': 0.564446,
#      'height': 0.966124},
#     'confidence': 0.981995}]},
#  {'frame_id': 414,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.425874,
#      'center_y': 0.498612,
#      'width': 0.554216,
#      'height': 0.960904},
#     'confidence': 0.992525}]},
#  {'frame_id': 415,
#   'filename': 'test.mp4',
#   'objects': [{'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.422907,
#      'center_y': 0.491634,
#      'width': 0.529106,
#      'height': 0.937421},
#     'confidence': 0.927402},
#    {'class_id': 0,
#     'name': 'person',
#     'relative_coordinates': {'center_x': 0.572609,
#      'center_y': 0.489575,
#      'width': 0.245466,
#      'height': 0.859077},
#     'confidence': 0.488355}]},
#  {'frame_id': 416, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 417, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 418, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 419, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 420, 'filename': 'test.mp4', 'objects': []},
#  {'frame_id': 421, 'filename': 'test.mp4', 'objects': []}]

# %% [markdown]
# # Algorithm:
# 1. Read JSON file
# 2. Create csv in format: # frame_id, filename, class_id, name, center_x, center_y, width, height, confidence

# %%
with open('result2.csv','w') as csv_file:
    csv_detl_head=''
    csv_detl_obj=''
    for each_entry in data:
        csv_detl_head=''
        csv_detl_obj=''
        csv_detl_head=csv_detl_head+str(each_entry.get("frame_id",'')) + ","
        csv_detl_head=csv_detl_head+each_entry.get("filename",'') + ","
        
        for each_key in each_entry:

            if "objects" in each_key and len(each_entry[each_key]): # handle object array
                for i in range (0,len(each_entry[each_key])):
                    temp_sub_dict=each_entry[each_key][i]
                    csv_detl_obj=( str(temp_sub_dict["class_id"]) + "," + temp_sub_dict["name"] + "," +
                          str(temp_sub_dict["relative_coordinates"]["center_x"]) + "," +
                          str(temp_sub_dict["relative_coordinates"]["center_y"]) + "," +
                          str(temp_sub_dict["relative_coordinates"]["width"]) + "," +
                          str(temp_sub_dict["relative_coordinates"]["height"]) + "," +
                          str(temp_sub_dict.get("confidence",''))
                         )
                    csv_file.write(csv_detl_head+csv_detl_obj+"\n")
            elif ("objects" in each_key):
                csv_file.write(csv_detl_head+ ",,,,,,"+"\n")

# %% [markdown]
# # Result verification aka Testing

# %%
# When read the output csv, add header and keep spaces as spaces
col_names=['frame_id', 'filename', 'class_id', 'name', 'center_x', 'center_y', 'width', 'height', 'confidence']
df=pd.read_csv("result2.csv",names=col_names,header=None,index_col=None)
df.fillna('', inplace=True)

# %%
df.head(2)
# Out:
#    frame_id  filename class_id name center_x center_y width height confidence
# 0         1  test.mp4
# 1         2  test.mp4

# %%
df.tail(10)
# Out:
#      frame_id  filename class_id    name  center_x  center_y     width  \
# 635       413  test.mp4        0  person  0.429068  0.503334  0.564446
# 636       414  test.mp4        0  person  0.425874  0.498612  0.554216
# 637       415  test.mp4        0  person  0.422907  0.491634  0.529106
# 638       415  test.mp4        0  person  0.572609  0.489575  0.245466
# 639       416  test.mp4
# 640       417  test.mp4
# 641       418  test.mp4
# 642       419  test.mp4
# 643       420  test.mp4
# 644       421  test.mp4
#
#        height confidence
# 635  0.966124   0.981995
# 636  0.960904   0.992525
# 637  0.937421   0.927402
# 638  0.859077   0.488355
# 639
# 640
# 641
# 642
# 643
# 644
